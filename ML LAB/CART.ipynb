# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import tree

# %%
data = pd.read_csv('CART_data.csv')
data.head()
# Out:
#     outlook temprerature humidity    wind play
# 0     sunny          hot     high    weak   no
# 1     sunny          hot     high  strong   no
# 2  overcast          hot     high    weak  yes
# 3      rain         mild     high    weak  yes
# 4      rain         cool   normal    weak  yes

# %%
y = data['play']
X = data.drop(['play'], axis=1)

dt_feature_names = list(one_hot_data.columns)
dt_target_names = [str(s) for s in y.unique()]


from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(max_depth = 3, random_state = 0)
dt.fit(one_hot_data,y)
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize = (12,10))
plot_tree(dt,feature_names = dt_feature_names, class_names = dt_target_names, filled = True)
# darker the color purer the node
# Out:
# [Text(372.0, 475.65000000000003, 'humidity_normal <= 0.5\ngini = 0.459\nsamples = 14\nvalue = [5, 9]\nclass = yes'),
#  Text(223.20000000000002, 339.75, 'outlook_sunny <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = no'),
#  Text(148.8, 203.85000000000002, 'wind_weak <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = yes'),
#  Text(74.4, 67.94999999999999, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = no'),
#  Text(223.20000000000002, 67.94999999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = yes'),
#  Text(297.6, 203.85000000000002, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = no'),
#  Text(520.8000000000001, 339.75, 'wind_weak <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = yes'),
#  Text(446.40000000000003, 203.85000000000002, 'outlook_rain <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = yes'),
#  Text(372.0, 67.94999999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = yes'),
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
import graphviz
from sklearn.tree import export_graphviz

# %%
from sklearn.tree.export import export_text
print(export_text(model,feature_names = dt_feature_names,show_weights = True))
# Out:
# |--- X1 <= 6.50
# |   |--- X2 <= 3.50
# |   |   |--- weights: [0.00, 3.00, 0.00] class: Yes
# |   |--- X2 >  3.50
# |   |   |--- X2 <= 4.50
# |   |   |   |--- weights: [0.00, 0.00, 1.00] class: yes
# |   |   |--- X2 >  4.50
# |   |   |   |--- weights: [0.00, 1.00, 0.00] class: Yes
# |--- X1 >  6.50
# |   |--- weights: [5.00, 0.00, 0.00] class: No

# %%
data = pd.read_csv('test.csv')
model = DecisionTreeClassifier()
model = model.fit(data[['X1', 'X2']], data.Y)
y = data['Y']
X = data.drop(['Y'], axis=1)
dt_feature_names = list(X.columns)
dt_target_names = [str(s) for s in y.unique()]
plt.figure(figsize = (8,6))
plot_tree(model,feature_names = dt_feature_names, class_names = dt_target_names, filled = True)
# Out:
# [Text(267.84000000000003, 285.39000000000004, 'X1 <= 6.5\ngini = 0.58\nsamples = 10\nvalue = [5, 4, 1]\nclass = yes'),
#  Text(178.56, 203.85000000000002, 'X2 <= 3.5\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1]\nclass = No'),
#  Text(89.28, 122.31, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]\nclass = No'),
#  Text(267.84000000000003, 122.31, 'X2 <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = No'),
#  Text(178.56, 40.76999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Yes'),
#  Text(357.12, 40.76999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = No'),
#  Text(357.12, 203.85000000000002, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]\nclass = yes')]

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0            7.0           3.2            4.7           1.4  Iris-versicolor
# 1            6.4           3.2            4.5           1.5  Iris-versicolor
# 2            6.9           3.1            4.9           1.5  Iris-versicolor
# 3            5.5           2.3            4.0           1.3  Iris-versicolor
# 4            6.5           2.8            4.6           1.5  Iris-versicolor

# %%
# Out:
# [Text(558.0, 611.55, 'PetalWidthCm <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [50, 50]\nclass = Iris-versicolor'),
#  Text(279.0, 203.85000000000002, 'gini = 0.168\nsamples = 54\nvalue = [49, 5]\nclass = Iris-versicolor'),
#  Text(837.0, 203.85000000000002, 'gini = 0.043\nsamples = 46\nvalue = [1, 45]\nclass = Iris-virginica')]

# %%
f
# Out:
# [[49  1]
#  [ 5 45]]
#                  precision    recall  f1-score   support
#
# Iris-versicolor       0.91      0.98      0.94        50
#  Iris-virginica       0.98      0.90      0.94        50
#
#        accuracy                           0.94       100
#       macro avg       0.94      0.94      0.94       100
#    weighted avg       0.94      0.94      0.94       100

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree,export_text
from sklearn.metrics import classification_report, confusion_matrix


data = pd.read_csv('CART_Iris_data.csv')
model = DecisionTreeClassifier(max_depth=1, min_samples_leaf=3)
# model = DecisionTreeClassifier()
model = model.fit(data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']], data.Species)

y = data['Species']
X = data.drop(['Species'], axis=1)
dt_feature_names = list(X.columns)
dt_target_names = [str(s) for s in y.unique()]
plt.figure(figsize = (10,8))
plot_tree(model,feature_names = dt_feature_names, class_names = dt_target_names, filled = True)

y_pred = model.predict(X)
print(confusion_matrix(y, y_pred))
print(classification_report(y, y_pred))
print(export_text(model,feature_names = dt_feature_names,show_weights = True))
# Out:
# [[49  1]
#  [ 5 45]]
#                  precision    recall  f1-score   support
#
# Iris-versicolor       0.91      0.98      0.94        50
#  Iris-virginica       0.98      0.90      0.94        50
#
#        accuracy                           0.94       100
#       macro avg       0.94      0.94      0.94       100
#    weighted avg       0.94      0.94      0.94       100
#
# |--- PetalWidthCm <= 1.75
# |   |--- weights: [49.00, 5.00] class: Iris-versicolor
# |--- PetalWidthCm >  1.75
# |   |--- weights: [1.00, 45.00] class: Iris-virginica

# %%
from sklearn.tree.export import export_text
print(export_text(model,feature_names = dt_feature_names,show_weights = True))
# Out:
# |--- PetalWidthCm <= 1.75
# |   |--- weights: [49.00, 5.00] class: Iris-versicolor
# |--- PetalWidthCm >  1.75
# |   |--- weights: [1.00, 45.00] class: Iris-virginica
